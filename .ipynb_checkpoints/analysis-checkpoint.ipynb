# %%
import pandas as pd

# %%
df = pd.read_csv('data/DataCoSupplyChainDataset.csv', encoding='latin1')

# %% [markdown]
# ## General View of the dataset

# %%
df.shape
# Out:
# (180519, 53)

# %%
df.columns
# Out:
# Index(['Type', 'Days for shipping (real)', 'Days for shipment (scheduled)',
#        'Benefit per order', 'Sales per customer', 'Delivery Status',
#        'Late_delivery_risk', 'Category Id', 'Category Name', 'Customer City',
#        'Customer Country', 'Customer Email', 'Customer Fname', 'Customer Id',
#        'Customer Lname', 'Customer Password', 'Customer Segment',
#        'Customer State', 'Customer Street', 'Customer Zipcode',
#        'Department Id', 'Department Name', 'Latitude', 'Longitude', 'Market',
#        'Order City', 'Order Country', 'Order Customer Id',
#        'order date (DateOrders)', 'Order Id', 'Order Item Cardprod Id',
#        'Order Item Discount', 'Order Item Discount Rate', 'Order Item Id',
#        'Order Item Product Price', 'Order Item Profit Ratio',
#        'Order Item Quantity', 'Sales', 'Order Item Total',
#        'Order Profit Per Order', 'Order Region', 'Order State', 'Order Status',
#        'Order Zipcode', 'Product Card Id', 'Product Category Id',
#        'Product Description', 'Product Image', 'Product Name', 'Product Price',
#        'Product Status', 'shipping date (DateOrders)', 'Shipping Mode'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Type                              object
# Days for shipping (real)           int64
# Days for shipment (scheduled)      int64
# Benefit per order                float64
# Sales per customer               float64
# Delivery Status                   object
# Late_delivery_risk                 int64
# Category Id                        int64
# Category Name                     object
# Customer City                     object
# Customer Country                  object
# Customer Email                    object
# Customer Fname                    object
# Customer Id                        int64
# Customer Lname                    object
# Customer Password                 object
# Customer Segment                  object
# Customer State                    object
# Customer Street                   object
# Customer Zipcode                 float64
# Department Id                      int64
# Department Name                   object
# Latitude                         float64
# Longitude                        float64
# Market                            object
# Order City                        object
# Order Country                     object
# Order Customer Id                  int64
# order date (DateOrders)           object
# Order Id                           int64
# Order Item Cardprod Id             int64
# Order Item Discount              float64
# Order Item Discount Rate         float64
# Order Item Id                      int64
# Order Item Product Price         float64
# Order Item Profit Ratio          float64
# Order Item Quantity                int64
# Sales                            float64
# Order Item Total                 float64
# Order Profit Per Order           float64
# Order Region                      object
# Order State                       object
# Order Status                      object
# Order Zipcode                    float64
# Product Card Id                    int64
# Product Category Id                int64
# Product Description              float64
# Product Image                     object
# Product Name                      object
# Product Price                    float64
# Product Status                     int64
# shipping date (DateOrders)        object
# Shipping Mode                     object
# dtype: object

# %% [markdown]
# # Split dataset into fact and dim tables for validation

# %%
columns = df.columns

# %% [markdown]
# ## Customers

# %%
customer_columns = [ x for x in columns if "Customer" in x and 'Order Customer Id' not in x]

# %%
customer_columns
# Out:
# ['Customer City',
#  'Customer Country',
#  'Customer Email',
#  'Customer Fname',
#  'Customer Id',
#  'Customer Lname',
#  'Customer Password',
#  'Customer Segment',
#  'Customer State',
#  'Customer Street',
#  'Customer Zipcode']

# %%
tb_dim_customers = df[customer_columns]

# %%
tb_dim_customers.shape
# Out:
# (180519, 11)

# %%
tb_dim_customers.head()
# Out:
#   Customer City Customer Country Customer Email Customer Fname  Customer Id  \
# 0        Caguas      Puerto Rico      XXXXXXXXX          Cally        20755
# 1        Caguas      Puerto Rico      XXXXXXXXX          Irene        19492
# 2      San Jose          EE. UU.      XXXXXXXXX        Gillian        19491
# 3   Los Angeles          EE. UU.      XXXXXXXXX           Tana        19490
# 4        Caguas      Puerto Rico      XXXXXXXXX           Orli        19489
#
#   Customer Lname Customer Password Customer Segment Customer State  \
# 0       Holloway         XXXXXXXXX         Consumer             PR
# 1           Luna         XXXXXXXXX         Consumer             PR
# 2      Maldonado         XXXXXXXXX         Consumer             CA
# 3           Tate         XXXXXXXXX      Home Office             CA
# 4      Hendricks         XXXXXXXXX        Corporate             PR
#
#             Customer Street  Customer Zipcode
# 0  5365 Noble Nectar Island             725.0
# 1          2679 Rustic Loop             725.0
# 2      8510 Round Bear Gate           95125.0
# 3           3200 Amber Bend           90027.0
# 4  8671 Iron Anchor Corners             725.0

# %% [markdown]
# ### Validate Customers

# %%
tb_dim_customers['Customer Id'].value_counts()
# Out:
# 5654     47
# 10591    45
# 5004     45
# 5715     44
# 3708     44
#          ..
# 18698     1
# 15537     1
# 15484     1
# 20681     1
# 2677      1
# Name: Customer Id, Length: 20652, dtype: int64

# %%
tb_dim_customers[tb_dim_customers['Customer Id'] == 5654]
# Out:
#        Customer City Customer Country Customer Email Customer Fname  \
# 6224          Caguas      Puerto Rico      XXXXXXXXX          Jerry
# 6754          Caguas      Puerto Rico      XXXXXXXXX          Jerry
# 6912          Caguas      Puerto Rico      XXXXXXXXX          Jerry
# 10652         Caguas      Puerto Rico      XXXXXXXXX          Jerry
# 10667         Caguas      Puerto Rico      XXXXXXXXX          Jerry
# 10795         Caguas      Puerto Rico      XXXXXXXXX          Jerry
# 11075         Caguas      Puerto Rico      XXXXXXXXX          Jerry
# 11497         Caguas      Puerto Rico      XXXXXXXXX          Jerry
# 11624         Caguas      Puerto Rico      XXXXXXXXX          Jerry
# 11736         Caguas      Puerto Rico      XXXXXXXXX          Jerry
# 30223         Caguas      Puerto Rico      XXXXXXXXX          Jerry
# 30236         Caguas      Puerto Rico      XXXXXXXXX          Jerry
# 33028         Caguas      Puerto Rico      XXXXXXXXX          Jerry
# 51532         Caguas      Puerto Rico      XXXXXXXXX          Jerry
# 55736         Caguas      Puerto Rico      XXXXXXXXX          Jerry
# 61162         Caguas      Puerto Rico      XXXXXXXXX          Jerry
# 73198         Caguas      Puerto Rico      XXXXXXXXX          Jerry
# 77071         Caguas      Puerto Rico      XXXXXXXXX          Jerry
# 79526         Caguas      Puerto Rico      XXXXXXXXX          Jerry
# 101390        Caguas      Puerto Rico      XXXXXXXXX          Jerry
# 111632        Caguas      Puerto Rico      XXXXXXXXX          Jerry
# 131624        Caguas      Puerto Rico      XXXXXXXXX          Jerry
# 140353        Caguas      Puerto Rico      XXXXXXXXX          Jerry
# 140355        Caguas      Puerto Rico      XXXXXXXXX          Jerry
# 140519        Caguas      Puerto Rico      XXXXXXXXX          Jerry
# 141590        Caguas      Puerto Rico      XXXXXXXXX          Jerry
# 142113        Caguas      Puerto Rico      XXXXXXXXX          Jerry
# 142133        Caguas      Puerto Rico      XXXXXXXXX          Jerry
# 142188        Caguas      Puerto Rico      XXXXXXXXX          Jerry
# 142197        Caguas      Puerto Rico      XXXXXXXXX          Jerry
# 145528        Caguas      Puerto Rico      XXXXXXXXX          Jerry
# 147189        Caguas      Puerto Rico      XXXXXXXXX          Jerry
# 148067        Caguas      Puerto Rico      XXXXXXXXX          Jerry
# 148163        Caguas      Puerto Rico      XXXXXXXXX          Jerry
# 148231        Caguas      Puerto Rico      XXXXXXXXX          Jerry
# 148317        Caguas      Puerto Rico      XXXXXXXXX          Jerry
# 149044        Caguas      Puerto Rico      XXXXXXXXX          Jerry
# 149095        Caguas      Puerto Rico      XXXXXXXXX          Jerry
# 149161        Caguas      Puerto Rico      XXXXXXXXX          Jerry
# 149171        Caguas      Puerto Rico      XXXXXXXXX          Jerry
# 149426        Caguas      Puerto Rico      XXXXXXXXX          Jerry
# 150152        Caguas      Puerto Rico      XXXXXXXXX          Jerry
# 150631        Caguas      Puerto Rico      XXXXXXXXX          Jerry
# 150638        Caguas      Puerto Rico      XXXXXXXXX          Jerry
# 150650        Caguas      Puerto Rico      XXXXXXXXX          Jerry
# 150761        Caguas      Puerto Rico      XXXXXXXXX          Jerry
# 153030        Caguas      Puerto Rico      XXXXXXXXX          Jerry
#
#         Customer Id Customer Lname Customer Password Customer Segment  \
# 6224           5654          Smith         XXXXXXXXX      Home Office
# 6754           5654          Smith         XXXXXXXXX      Home Office
# 6912           5654          Smith         XXXXXXXXX      Home Office
# 10652          5654          Smith         XXXXXXXXX      Home Office
# 10667          5654          Smith         XXXXXXXXX      Home Office
# 10795          5654          Smith         XXXXXXXXX      Home Office
# 11075          5654          Smith         XXXXXXXXX      Home Office
# 11497          5654          Smith         XXXXXXXXX      Home Office
# 11624          5654          Smith         XXXXXXXXX      Home Office
# 11736          5654          Smith         XXXXXXXXX      Home Office
# 30223          5654          Smith         XXXXXXXXX      Home Office
# 30236          5654          Smith         XXXXXXXXX      Home Office
# 33028          5654          Smith         XXXXXXXXX      Home Office
# 51532          5654          Smith         XXXXXXXXX      Home Office
# 55736          5654          Smith         XXXXXXXXX      Home Office
# 61162          5654          Smith         XXXXXXXXX      Home Office
# 73198          5654          Smith         XXXXXXXXX      Home Office
# 77071          5654          Smith         XXXXXXXXX      Home Office
# 79526          5654          Smith         XXXXXXXXX      Home Office
# 101390         5654          Smith         XXXXXXXXX      Home Office
# 111632         5654          Smith         XXXXXXXXX      Home Office
# 131624         5654          Smith         XXXXXXXXX      Home Office
# 140353         5654          Smith         XXXXXXXXX      Home Office
# 140355         5654          Smith         XXXXXXXXX      Home Office
# 140519         5654          Smith         XXXXXXXXX      Home Office
# 141590         5654          Smith         XXXXXXXXX      Home Office
# 142113         5654          Smith         XXXXXXXXX      Home Office
# 142133         5654          Smith         XXXXXXXXX      Home Office
# 142188         5654          Smith         XXXXXXXXX      Home Office
# 142197         5654          Smith         XXXXXXXXX      Home Office
# 145528         5654          Smith         XXXXXXXXX      Home Office
# 147189         5654          Smith         XXXXXXXXX      Home Office
# 148067         5654          Smith         XXXXXXXXX      Home Office
# 148163         5654          Smith         XXXXXXXXX      Home Office
# 148231         5654          Smith         XXXXXXXXX      Home Office
# 148317         5654          Smith         XXXXXXXXX      Home Office
# 149044         5654          Smith         XXXXXXXXX      Home Office
# 149095         5654          Smith         XXXXXXXXX      Home Office
# 149161         5654          Smith         XXXXXXXXX      Home Office
# 149171         5654          Smith         XXXXXXXXX      Home Office
# 149426         5654          Smith         XXXXXXXXX      Home Office
# 150152         5654          Smith         XXXXXXXXX      Home Office
# 150631         5654          Smith         XXXXXXXXX      Home Office
# 150638         5654          Smith         XXXXXXXXX      Home Office
# 150650         5654          Smith         XXXXXXXXX      Home Office
# 150761         5654          Smith         XXXXXXXXX      Home Office
# 153030         5654          Smith         XXXXXXXXX      Home Office
#
#        Customer State    Customer Street  Customer Zipcode
# 6224               PR  9293 Hidden Vista             725.0
# 6754               PR  9293 Hidden Vista             725.0
# 6912               PR  9293 Hidden Vista             725.0
# 10652              PR  9293 Hidden Vista             725.0
# 10667              PR  9293 Hidden Vista             725.0
# 10795              PR  9293 Hidden Vista             725.0
# 11075              PR  9293 Hidden Vista             725.0
# 11497              PR  9293 Hidden Vista             725.0
# 11624              PR  9293 Hidden Vista             725.0
# 11736              PR  9293 Hidden Vista             725.0
# 30223              PR  9293 Hidden Vista             725.0
# 30236              PR  9293 Hidden Vista             725.0
# 33028              PR  9293 Hidden Vista             725.0
# 51532              PR  9293 Hidden Vista             725.0
# 55736              PR  9293 Hidden Vista             725.0
# 61162              PR  9293 Hidden Vista             725.0
# 73198              PR  9293 Hidden Vista             725.0
# 77071              PR  9293 Hidden Vista             725.0
# 79526              PR  9293 Hidden Vista             725.0
# 101390             PR  9293 Hidden Vista             725.0
# 111632             PR  9293 Hidden Vista             725.0
# 131624             PR  9293 Hidden Vista             725.0
# 140353             PR  9293 Hidden Vista             725.0
# 140355             PR  9293 Hidden Vista             725.0
# 140519             PR  9293 Hidden Vista             725.0
# 141590             PR  9293 Hidden Vista             725.0
# 142113             PR  9293 Hidden Vista             725.0
# 142133             PR  9293 Hidden Vista             725.0
# 142188             PR  9293 Hidden Vista             725.0
# 142197             PR  9293 Hidden Vista             725.0
# 145528             PR  9293 Hidden Vista             725.0
# 147189             PR  9293 Hidden Vista             725.0
# 148067             PR  9293 Hidden Vista             725.0
# 148163             PR  9293 Hidden Vista             725.0
# 148231             PR  9293 Hidden Vista             725.0
# 148317             PR  9293 Hidden Vista             725.0
# 149044             PR  9293 Hidden Vista             725.0
# 149095             PR  9293 Hidden Vista             725.0
# 149161             PR  9293 Hidden Vista             725.0
# 149171             PR  9293 Hidden Vista             725.0
# 149426             PR  9293 Hidden Vista             725.0
# 150152             PR  9293 Hidden Vista             725.0
# 150631             PR  9293 Hidden Vista             725.0
# 150638             PR  9293 Hidden Vista             725.0
# 150650             PR  9293 Hidden Vista             725.0
# 150761             PR  9293 Hidden Vista             725.0
# 153030             PR  9293 Hidden Vista             725.0

# %%
tb_dim_customers.drop_duplicates(subset='Customer Id', inplace=True)
# Out:
# /tmp/ipykernel_41976/3049277074.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tb_dim_customers.drop_duplicates(subset='Customer Id', keep=False, inplace=True)

# %%
tb_dim_customers.shape
# Out:
# (8435, 11)

# %%
tb_dim_customers['Customer Id'].value_counts(ascending=False)
# Out:
# 20755    1
# 13955    1
# 14255    1
# 15168    1
# 17722    1
#         ..
# 13985    1
# 13949    1
# 12815    1
# 12761    1
# 2677     1
# Name: Customer Id, Length: 8435, dtype: int64

# %%
tb_dim_customers[tb_dim_customers['Customer Id'] == 5654]
# Out:
# Empty DataFrame
# Columns: [Customer City, Customer Country, Customer Email, Customer Fname, Customer Id, Customer Lname, Customer Password, Customer Segment, Customer State, Customer Street, Customer Zipcode]
# Index: []
