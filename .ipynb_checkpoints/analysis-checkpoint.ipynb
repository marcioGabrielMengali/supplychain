# %% [markdown]
# # SupplyChain Analysist For Fact and Dim Tables

# %%
import pandas as pd

# %% [markdown]
# # Read File

# %%
df = pd.read_csv('data/DataCoSupplyChainDataset.csv', encoding='latin1')

# %% [markdown]
# # Overview Of The Dataset

# %%
df.shape
# Out:
# (180519, 53)

# %%
df.columns
# Out:
# Index(['Type', 'Days for shipping (real)', 'Days for shipment (scheduled)',
#        'Benefit per order', 'Sales per customer', 'Delivery Status',
#        'Late_delivery_risk', 'Category Id', 'Category Name', 'Customer City',
#        'Customer Country', 'Customer Email', 'Customer Fname', 'Customer Id',
#        'Customer Lname', 'Customer Password', 'Customer Segment',
#        'Customer State', 'Customer Street', 'Customer Zipcode',
#        'Department Id', 'Department Name', 'Latitude', 'Longitude', 'Market',
#        'Order City', 'Order Country', 'Order Customer Id',
#        'order date (DateOrders)', 'Order Id', 'Order Item Cardprod Id',
#        'Order Item Discount', 'Order Item Discount Rate', 'Order Item Id',
#        'Order Item Product Price', 'Order Item Profit Ratio',
#        'Order Item Quantity', 'Sales', 'Order Item Total',
#        'Order Profit Per Order', 'Order Region', 'Order State', 'Order Status',
#        'Order Zipcode', 'Product Card Id', 'Product Category Id',
#        'Product Description', 'Product Image', 'Product Name', 'Product Price',
#        'Product Status', 'shipping date (DateOrders)', 'Shipping Mode'],
#       dtype='object')

# %%
df.head()
# Out:
#        Type  Days for shipping (real)  Days for shipment (scheduled)  \
# 0     DEBIT                         3                              4
# 1  TRANSFER                         5                              4
# 2      CASH                         4                              4
# 3     DEBIT                         3                              4
# 4   PAYMENT                         2                              4
#
#    Benefit per order  Sales per customer   Delivery Status  \
# 0          91.250000          314.640015  Advance shipping
# 1        -249.089996          311.359985     Late delivery
# 2        -247.779999          309.720001  Shipping on time
# 3          22.860001          304.809998  Advance shipping
# 4         134.210007          298.250000  Advance shipping
#
#    Late_delivery_risk  Category Id   Category Name Customer City  ...  \
# 0                   0           73  Sporting Goods        Caguas  ...
# 1                   1           73  Sporting Goods        Caguas  ...
# 2                   0           73  Sporting Goods      San Jose  ...
# 3                   0           73  Sporting Goods   Los Angeles  ...
# 4                   0           73  Sporting Goods        Caguas  ...
#
#   Order Zipcode Product Card Id Product Category Id  Product Description  \
# 0           NaN            1360                  73                  NaN
# 1           NaN            1360                  73                  NaN
# 2           NaN            1360                  73                  NaN
# 3           NaN            1360                  73                  NaN
# 4           NaN            1360                  73                  NaN
#
#                                   Product Image  Product Name Product Price  \
# 0  http://images.acmesports.sports/Smart+watch   Smart watch         327.75
# 1  http://images.acmesports.sports/Smart+watch   Smart watch         327.75
# 2  http://images.acmesports.sports/Smart+watch   Smart watch         327.75
# 3  http://images.acmesports.sports/Smart+watch   Smart watch         327.75
# 4  http://images.acmesports.sports/Smart+watch   Smart watch         327.75
#
#   Product Status shipping date (DateOrders)   Shipping Mode
# 0              0             2/3/2018 22:56  Standard Class
# 1              0            1/18/2018 12:27  Standard Class
# 2              0            1/17/2018 12:06  Standard Class
# 3              0            1/16/2018 11:45  Standard Class
# 4              0            1/15/2018 11:24  Standard Class
#
# [5 rows x 53 columns]

# %%
df[['Department Id', 'Department Name']]
# Out:
#         Department Id Department Name
# 0                   2         Fitness
# 1                   2         Fitness
# 2                   2         Fitness
# 3                   2         Fitness
# 4                   2         Fitness
# ...               ...             ...
# 180514              7        Fan Shop
# 180515              7        Fan Shop
# 180516              7        Fan Shop
# 180517              7        Fan Shop
# 180518              7        Fan Shop
#
# [180519 rows x 2 columns]

# %%
df[['Category Id', 'Category Name']]
# Out:
#         Category Id   Category Name
# 0                73  Sporting Goods
# 1                73  Sporting Goods
# 2                73  Sporting Goods
# 3                73  Sporting Goods
# 4                73  Sporting Goods
# ...             ...             ...
# 180514           45         Fishing
# 180515           45         Fishing
# 180516           45         Fishing
# 180517           45         Fishing
# 180518           45         Fishing
#
# [180519 rows x 2 columns]

# %% [markdown]
# # Tb Fact Sales

# %%
tb_fact_sales = df[['Order Id', 'Order Item Id', 'Sales']]

# %%
tb_fact_sales.shape
# Out:
# (180519, 3)

# %%
tb_fact_sales.head()
# Out:
#    Order Id  Order Item Id   Sales
# 0     77202         180517  327.75
# 1     75939         179254  327.75
# 2     75938         179253  327.75
# 3     75937         179252  327.75
# 4     75936         179251  327.75

# %%
tb_fact_sales['Order Id'].value_counts(ascending=False)
# Out:
# Order Id
# 48880    5
# 3605     5
# 28265    5
# 50037    5
# 27861    5
#         ..
# 42011    1
# 42068    1
# 42072    1
# 42118    1
# 26118    1
# Name: count, Length: 65752, dtype: int64

# %%
tb_fact_sales['Order Id'].value_counts(ascending=False)
# Out:
# Order Id
# 48880    5
# 3605     5
# 28265    5
# 50037    5
# 27861    5
#         ..
# 42011    1
# 42068    1
# 42072    1
# 42118    1
# 26118    1
# Name: count, Length: 65752, dtype: int64

# %%
tb_fact_sales[tb_fact_sales['Order Id'] == 48880]
# Out:
#         Order Id  Order Item Id       Sales
# 118698     48880         122220  129.990005
# 119105     48880         122221  199.979996
# 119676     48880         122222  159.960007
# 119677     48880         122218  159.960007
# 119995     48880         122219  250.000000

# %% [markdown]
# # Order

# %%
tb_dim_order = df[['Order Id', 'order date (DateOrders)', 'Order Status', 'Market', 'Order Region', 'Order Country', 'Order State', 'Order City', 'Customer Id']]

# %%
tb_dim_order.shape
# Out:
# (180519, 9)

# %%
tb_dim_order.head()
# Out:
#    Order Id order date (DateOrders)     Order Status        Market  \
# 0     77202         1/31/2018 22:56         COMPLETE  Pacific Asia
# 1     75939         1/13/2018 12:27          PENDING  Pacific Asia
# 2     75938         1/13/2018 12:06           CLOSED  Pacific Asia
# 3     75937         1/13/2018 11:45         COMPLETE  Pacific Asia
# 4     75936         1/13/2018 11:24  PENDING_PAYMENT  Pacific Asia
#
#      Order Region Order Country      Order State  Order City  Customer Id
# 0  Southeast Asia     Indonesia  Java Occidental      Bekasi        20755
# 1      South Asia         India         Rajastán     Bikaner        19492
# 2      South Asia         India         Rajastán     Bikaner        19491
# 3         Oceania     Australia       Queensland  Townsville        19490
# 4         Oceania     Australia       Queensland  Townsville        19489

# %%
tb_dim_order['Order Id'].value_counts(ascending=False)
# Out:
# Order Id
# 48880    5
# 3605     5
# 28265    5
# 50037    5
# 27861    5
#         ..
# 42011    1
# 42068    1
# 42072    1
# 42118    1
# 26118    1
# Name: count, Length: 65752, dtype: int64

# %%
tb_dim_order[tb_dim_order['Order Id'] == 48880]
# Out:
#         Order Id order date (DateOrders) Order Status        Market  \
# 118698     48880        12/14/2016 12:29   PROCESSING  Pacific Asia
# 119105     48880        12/14/2016 12:29   PROCESSING  Pacific Asia
# 119676     48880        12/14/2016 12:29   PROCESSING  Pacific Asia
# 119677     48880        12/14/2016 12:29   PROCESSING  Pacific Asia
# 119995     48880        12/14/2016 12:29   PROCESSING  Pacific Asia
#
#        Order Region Order Country    Order State   Order City  Customer Id
# 118698    West Asia  Arabia Saudí  Ash Sharqiyah  Al Mubarraz         3714
# 119105    West Asia  Arabia Saudí  Ash Sharqiyah  Al Mubarraz         3714
# 119676    West Asia  Arabia Saudí  Ash Sharqiyah  Al Mubarraz         3714
# 119677    West Asia  Arabia Saudí  Ash Sharqiyah  Al Mubarraz         3714
# 119995    West Asia  Arabia Saudí  Ash Sharqiyah  Al Mubarraz         3714

# %%
tb_dim_order[tb_dim_order['Order Id'] == 3605]
# Out:
#        Order Id order date (DateOrders) Order Status Market     Order Region  \
# 62362      3605         2/22/2015 14:38   PROCESSING  LATAM  Central America
# 62369      3605         2/22/2015 14:38   PROCESSING  LATAM  Central America
# 85845      3605         2/22/2015 14:38   PROCESSING  LATAM  Central America
# 87115      3605         2/22/2015 14:38   PROCESSING  LATAM  Central America
# 87117      3605         2/22/2015 14:38   PROCESSING  LATAM  Central America
#
#       Order Country Order State Order City  Customer Id
# 62362     Nicaragua     Managua    Managua         6083
# 62369     Nicaragua     Managua    Managua         6083
# 85845     Nicaragua     Managua    Managua         6083
# 87115     Nicaragua     Managua    Managua         6083
# 87117     Nicaragua     Managua    Managua         6083

# %%
tb_dim_order.columns
# Out:
# Index(['Order Id', 'order date (DateOrders)', 'Order Status', 'Market',
#        'Order Region', 'Order Country', 'Order State', 'Order City',
#        'Customer Id'],
#       dtype='object')

# %%
tb_dim_order_grouped = tb_dim_order.groupby(by=['Order Id'])['Customer Id'].nunique().to_frame()

# %%
tb_dim_order_grouped.sort_values(by='Customer Id',ascending=False)
# Out:
#           Customer Id
# Order Id
# 1                   1
# 52691               1
# 52578               1
# 52579               1
# 52580               1
# ...               ...
# 26243               1
# 26244               1
# 26245               1
# 26246               1
# 77204               1
#
# [65752 rows x 1 columns]

# %%
tb_dim_order_grouped.columns
# Out:
# Index(['Customer Id'], dtype='object')

# %%
tb_dim_order_grouped[tb_dim_order_grouped.index == 48880]
# Out:
#           Customer Id
# Order Id
# 48880               1

# %%
tb_dim_order_grouped = tb_dim_order.groupby(by=['Order Id'])['Order Status'].nunique().to_frame()

# %%
tb_dim_order_grouped.sort_values(by='Order Status',ascending=False)
# Out:
#           Order Status
# Order Id
# 1                    1
# 52691                1
# 52578                1
# 52579                1
# 52580                1
# ...                ...
# 26243                1
# 26244                1
# 26245                1
# 26246                1
# 77204                1
#
# [65752 rows x 1 columns]

# %%
tb_dim_order.drop_duplicates(subset=['Order Id'], inplace=True)
# Out:
# /tmp/ipykernel_1195/1169094549.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tb_dim_order.drop_duplicates(subset=['Order Id'], inplace=True)

# %%
tb_dim_order.shape
# Out:
# (65752, 9)

# %%
tb_dim_order.head()
# Out:
#    Order Id order date (DateOrders)     Order Status        Market  \
# 0     77202         1/31/2018 22:56         COMPLETE  Pacific Asia
# 1     75939         1/13/2018 12:27          PENDING  Pacific Asia
# 2     75938         1/13/2018 12:06           CLOSED  Pacific Asia
# 3     75937         1/13/2018 11:45         COMPLETE  Pacific Asia
# 4     75936         1/13/2018 11:24  PENDING_PAYMENT  Pacific Asia
#
#      Order Region Order Country      Order State  Order City  Customer Id
# 0  Southeast Asia     Indonesia  Java Occidental      Bekasi        20755
# 1      South Asia         India         Rajastán     Bikaner        19492
# 2      South Asia         India         Rajastán     Bikaner        19491
# 3         Oceania     Australia       Queensland  Townsville        19490
# 4         Oceania     Australia       Queensland  Townsville        19489

# %% [markdown]
# # Order Itemm
